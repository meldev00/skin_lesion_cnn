# %% [markdown]
# > This notebook is dedicated to playing around with manipulating and augmenting image data.

# %%
import pandas as pd
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import PIL
from PIL import Image
from matplotlib import image
import matplotlib.pyplot as plt

# %%
fig1 = plt.figure()

vis_im  = Image.open("../skin-cancer-mnist-ham10000/image_data_test/type_0/ISIC_0024843.jpg")
vis_im

# fig1.savefig("../images/type0_sample.png")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x63AB85470>

# %%
im = image.imread("../skin-cancer-mnist-ham10000/image_data_test/type_0/ISIC_0024843.jpg")

# %%
imgen = ImageDataGenerator(
        rescale = 1./255,
        rotation_range = 360,
        width_shift_range = 0.2,
        height_shift_range = 0.2,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,
        vertical_flip = True
)

# %%
new_im = imgen.apply_transform(im, {"theta": 50,
                                    "flip_vertical": True})

# %%
Image.fromarray(new_im)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x63ABB1358>

# %%
im_dict = imgen.get_random_transform((48,48,3))

# %%
new_im2 = imgen.apply_transform(im, im_dict)

# %%
Image.fromarray(new_im2)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x63A434FD0>

# %% [markdown]
# > The "apply transform" and "get random transform will be useful for creating more augmented data.

# %%
fig = plt.figure()

vis_im  = Image.open("../skin-cancer-mnist-ham10000/image_data_test/type_4/ISIC_0024327.jpg")
vis_im

# fig.savefig("../images/type2_sample.png")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x63ABB1160>

# %%
im = image.imread("../skin-cancer-mnist-ham10000/image_data_test/type_4/ISIC_0024327.jpg")

# %%
new_im2 = imgen.apply_transform(im, im_dict)

# %%
Image.fromarray(new_im2)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x63AB8FAC8>

# %%
im_dict = imgen.get_random_transform((48,48,3))
new_im3 = imgen.apply_transform(im, im_dict)

# %%
Image.fromarray(new_im3)
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x63B6DE0B8>
